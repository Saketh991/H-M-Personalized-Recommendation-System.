# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import operator

# %%
#Use the transactions train subset
transactions_df = pd.read_csv("transactions_train_subset.csv")

# %%
transactions_df
# Out:
#                t_dat  ... sales_channel_id
# 0         2018-09-20  ...                2
# 1         2018-09-20  ...                2
# 2         2018-09-20  ...                2
# 3         2018-09-20  ...                2
# 4         2018-09-20  ...                2
# ...              ...  ...              ...
# 13310255  2020-09-15  ...                2
# 13310256  2020-09-15  ...                1
# 13310257  2020-09-15  ...                1
# 13310258  2020-09-15  ...                1
# 13310259  2020-09-15  ...                1
#
# [13310260 rows x 5 columns]

# %%
#Use the transactions test subset
transactions_test=pd.read_csv("transactions_test_subset.csv")

# %%
transactions_test
# Out:
#                                              customer_id  \
# 0      00077dbd5c4a4991e092e63893ccf29294a9d5c46e8501...
# 1      000fb6e772c5d0023892065e659963da90b1866035558e...
# 2      0010e8eb18f131e724d6997909af0808adbba057529edb...
# 3      001143bec624de9df82bd687babb382e00b0285e2371cc...
# 4      001c1f8d70782f450524d3b3f404474dbd4a7d0d2ad78a...
# ...                                                  ...
# 20276  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 20277  fff3573d9131d15da6a46c1ca8f03b5d37e4f6b804171e...
# 20278  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 20279  fff7e7674509592818bf453391af43a85eaaac9a52d858...
# 20280  fffae8eb3a282d8c43c77dd2ca0621703b71e90904dfde...
#
#                                                 products
# 0      [903762001 879189005 158340001 867966009 91552...
# 1      [786022008 913272003 889669006 913272003 88966...
# 2      [237347060 562245001 610776105 456163060 91444...
# 3      [759814034 759814034 837443001 890631002 90795...
# 4                                            [898886002]
# ...                                                  ...
# 20276  [759054001 697564010 891322004 891322004 91889...
# 20277  [783517006 813298001 873279001 914805006 91552...
# 20278                                        [833459002]
# 20279                                        [624486049]
# 20280  [396135007 817472007 715624050 817472003 89432...
#
# [20281 rows x 2 columns]

# %%
customers_df = pd.read_csv("customers_subset.csv")

# %%
articles_df = pd.read_csv("articles_subset.csv")

# %%
#Group by the data with the customer id column to get the transactions of each customer
temp = transactions_df.drop(['price','sales_channel_id','t_dat'],axis=1).groupby("customer_id")

# %% [markdown]
# **Generating Item-Feature Matrix**

# %%
features = ['article_id','product_group_name', 
       'graphical_appearance_name', 'colour_group_name',
       'perceived_colour_value_name',
       'perceived_colour_master_name',
       'department_name', 'index_name',
       'index_group_name', 'section_name',
       'garment_group_name']

# %%
articles_df=articles_df[features]

# %%
#Get the item-feature of the articles using dummies
item_feature = pd.get_dummies(articles_df)

# %%
item_feature=item_feature.set_index("article_id")

# %%
# Calculate the similarity between item-item using cosine similarity.
item_feature1 = cosine_similarity(item_feature)
item_feature1
# Out:
# array([[1. , 0.7, 0.6, ..., 0.3, 0.7, 0.6],
#        [0.7, 1. , 0.7, ..., 0. , 0.4, 0.3],
#        [0.6, 0.7, 1. , ..., 0. , 0.3, 0.2],
#        ...,
#        [0.3, 0. , 0. , ..., 1. , 0.3, 0.3],
#        [0.7, 0.4, 0.3, ..., 0.3, 1. , 0.8],
#        [0.6, 0.3, 0.2, ..., 0.3, 0.8, 1. ]])

# %%
# Convert it into a dataframe
item_feature1=pd.DataFrame(item_feature1,columns=item_feature.index)
item_feature1=item_feature1.set_index(item_feature.index)

# %%
item_feature1
# Out:
# article_id  108775015  108775044  108775051  ...  953450001  953763001  956217002
# article_id                                   ...
# 108775015         1.0        0.7        0.6  ...        0.3        0.7        0.6
# 108775044         0.7        1.0        0.7  ...        0.0        0.4        0.3
# 108775051         0.6        0.7        1.0  ...        0.0        0.3        0.2
# 110065001         0.5        0.2        0.1  ...        0.3        0.5        0.5
# 110065002         0.2        0.5        0.2  ...        0.0        0.2        0.2
# ...               ...        ...        ...  ...        ...        ...        ...
# 952267001         0.4        0.1        0.1  ...        0.5        0.4        0.4
# 952938001         0.3        0.3        0.3  ...        0.0        0.5        0.5
# 953450001         0.3        0.0        0.0  ...        1.0        0.3        0.3
# 953763001         0.7        0.4        0.3  ...        0.3        1.0        0.8
# 956217002         0.6        0.3        0.2  ...        0.3        0.8        1.0
#
# [99773 rows x 99773 columns]

# %% [markdown]
# **Generating User feature matrix**

# %%
articles = articles_df[features]
merged_data = temp[['customer_id', 'article_id']].merge(item_feature, on='article_id', how='left')

# %%
merged_data.shape
# Out:
# (13310260, 471)

# %%
user_feature=merged_data.groupby("customer_id")[merged_data.columns[2:]].sum()

# %%
user_feature
# Out:
#                                                     product_group_name_Accessories  ...  garment_group_name_Woven/Jersey/Knitted mix Baby
# customer_id                                                                         ...
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...                             4.0  ...                                               3.0
# 00007d2de826758b65a93dd24ce629ed66842531df66993...                             4.0  ...                                               0.0
# 00009d946eec3ea54add5ba56d5210ea898def4b46c6857...                             5.0  ...                                               0.0
# 0000f1c71aafe5963c3d195cf273f7bfd50bbf17761c919...                             3.0  ...                                               0.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                            34.0  ...                                               0.0
# ...                                                                            ...  ...                                               ...
# fffae8eb3a282d8c43c77dd2ca0621703b71e90904dfde2...                             2.0  ...                                               0.0
# fffb68e203e88449a1dc7173e938b1b3e91b0c93ff4e1dd...                             0.0  ...                                               0.0
# fffb834e3b357155d4f72274f3621f68db9c4bac221851b...                             3.0  ...                                               0.0
# fffe7116f9f68e8ad287fd7b6e33aad4871d7080e77d2d5...                             6.0  ...                                               0.0
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...                             5.0  ...                                               1.0
#
# [105324 rows x 468 columns]

# %%
#Scale the user feature data by using Min-Max scaler
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(p.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=p.columns,index= p.index)

# %%
user_feature = df_scaled

# %%
user_feature

# %% [markdown]
# **Generating User-Item Score Matrix**

# %%
user_item_score = user_feature.dot(item_feature.T)

# %%
user_item_score=user_item_score.sort_index()

# %%
user_item_score
# Out:
# article_id                                          108775015  ...  956217002
# customer_id                                                    ...
# 00077dbd5c4a4991e092e63893ccf29294a9d5c46e85010...   0.348827  ...   0.299725
# 000fb6e772c5d0023892065e659963da90b1866035558ec...   2.072309  ...   1.975734
# 0010e8eb18f131e724d6997909af0808adbba057529edb1...   0.567452  ...   0.363594
# 001143bec624de9df82bd687babb382e00b0285e2371cc9...   0.294870  ...   0.357514
# 001c1f8d70782f450524d3b3f404474dbd4a7d0d2ad78a0...   0.479446  ...   0.459095
# ...                                                       ...  ...        ...
# fff2282977442e327b45d8c89afde25617d00124d0f9998...   1.711409  ...   1.897199
# fff3573d9131d15da6a46c1ca8f03b5d37e4f6b804171ea...   0.917456  ...   1.169438
# fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e59...   0.366454  ...   0.352305
# fff7e7674509592818bf453391af43a85eaaac9a52d8587...   0.734707  ...   0.713000
# fffae8eb3a282d8c43c77dd2ca0621703b71e90904dfde2...   0.852350  ...   0.878183
#
# [20281 rows x 99773 columns]

# %%
groupby_customer = merged_data.groupby('customer_id')
groups = dict(list(groupby_customer))
# To get the recommendations for the given customer_id.
def get_rcmnd(customer_id, scores,groups):
    customer_scores = scores.loc[customer_id]
    customer_prev_items=groups[customer_id]['article_id'].values
    customer_prev_items = groupby_customer.get_group(customer_id)['article_id']
    prev_dropped = scores.loc[customer_id]
    return prev_dropped.sort_values(ascending=False)

# %% [markdown]
# **To get the recommendations using item-item collaborative filtering.**

# %%
test_predictions=pd.DataFrame(columns=["customer_id","predictions"])
def similar_items(customer_id,item_feature1,user_item_score,test_predictions):
  k=12
  # Get the list of articles for which the customer don't have score.
  s=(user_item_score.loc[customer_id].keys()[user_item_score.loc[customer_id]==0]).values
  # Get the list of articles for which the customer has score.
  m=(user_item_score.loc[customer_id].keys()[user_item_score.loc[customer_id]!=0]).values
  for i in s:
    #For each article get the top 10 similar articles
    j=dict(item_feature1.loc[i])
    sorted_items=[i[1] for i in sorted(x.items(), key=operator.itemgetter(1))][:10]
    score=0
    n=0
    for sort in sorted_items:
      if sort in m:
        #Calculate the score for the unscored article
        score+=user_item_score.loc[customer_id,sort]*item_feature1.loc[i,sort]
        n+=item_feature1.loc[i,sort]
    if n!=0:  
      #Take this score as the rating for the unrated article.
      user_item_score.at[customer_id,i]=score/n
  # Get recommendations for the given customer after calculating scores for the articles which the customer did'nt bought.
  rcmnds=get_rcmnd(customer_id, user_item_score,groups).index.values[:k]
  # Add the predictions of the customer to the test predictions dataframe.
  test_predictions=test_predictions.append({"customer_id":customer_id,"predictions":rcmnds},ignore_index=True)
  return test_predictions

# %%
#Calculate the predictions for the entire test customer data.
for i in user_item_score.index:
    test_predictions=similar_items(i,item_feature1,user_item_score,test_predictions)

# %%
# Show the first top 10 predictions.
test_predictions.head(10)
# Out:
#                                          customer_id  \
# 0  00077dbd5c4a4991e092e63893ccf29294a9d5c46e8501...
# 1  000fb6e772c5d0023892065e659963da90b1866035558e...
# 2  0010e8eb18f131e724d6997909af0808adbba057529edb...
# 3  001143bec624de9df82bd687babb382e00b0285e2371cc...
# 4  001c1f8d70782f450524d3b3f404474dbd4a7d0d2ad78a...
# 5  001ddeb8fb74fec5693116da83b488e05ee9a9e179f3fd...
# 6  00201f34c8c92683263346d78c2b45ffd0c6927229542d...
# 7  002253f0e3869ca2833ca2dfec4f8995ad9cdf8ca2333a...
# 8  00250644a9628fb8c4aebabf555d3caabe44c99c74fbcf...
# 9  0026906d6c593cd34993ee283861e050272cb193026eb8...
#
#                                          predictions
# 0  [407663008 590494001 654100005 726130002 69500...
# 1  [769263002 703399003 791488007 575535008 86493...
# 2  [763157006 550445003 610776007 456163002 68181...
# 3  [779574001 829358001 749484006 660200003 66206...
# 4  [663236002 738881001 711431007 760866002 87475...
# 5  [564312033 564314034 564310037 564314020 56431...
# 6  [780724002 760656003 755473003 589818006 82735...
# 7  [588533002 691736006 554541029 803160002 81141...
# 8  [764598002 736066005 711193004 729315004 72013...
# 9  [684021091 699923105 621523006 581994009 73086...

# %%
test_predictions.to_csv(f"test_predictions_collab.csv",index=False)
